# %%
import pandas as pd
import numpy as np
import time

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from scipy import stats
from sklearn.linear_model import LinearRegression
from tqdm.notebook import tqdm

pd.set_option("display.width", 500)
pd.set_option("display.max_columns", 100)

# %%
DAY_INTERVAL = 7
MAX_DAYS = 735
DAY_LIMITS = list(range(DAY_INTERVAL, MAX_DAYS + 1, DAY_INTERVAL))

# %%
def load_users(users_path: str, super_users_path: str) -> pd.DataFrame:
    """
    Load and preprocess user data, excluding super users from regular users.
    Flags optional fields as True/False based on their presence.
    """
    start_time = time.time()
    # Columns to load
    user_cols = ["Id", "CreationDate", "AboutMe", "Location", "WebsiteUrl"]

    # Load user data
    users = pd.read_parquet(users_path, columns=user_cols)
    super_users = pd.read_parquet(super_users_path, columns=user_cols)
    print(f"{time.time() - start_time:.2f}s: Users and Super Users loaded.")

    # Mark super users
    super_users["SuperUser"] = True
    users["SuperUser"] = False

    # Remove super users from regular users using set for faster lookup
    super_user_ids = set(super_users["Id"])
    users = users[~users["Id"].isin(super_user_ids)]

    # Concatenate regular and super users
    all_users = pd.concat([users, super_users], ignore_index=True)
    print(f"{time.time() - start_time:.2f}s: Super Users removed from regular users and concatenated.")

    # Convert CreationDate to datetime
    all_users["CreationDate"] = pd.to_datetime(all_users["CreationDate"], errors="coerce")

    # Filter out users with non-positive Id
    all_users = all_users[all_users["Id"] > 0]

    # Implement flags for optional fields
    optional_fields = ["AboutMe", "Location", "WebsiteUrl"]
    for field in optional_fields:
        all_users[f"{field}_Present"] = all_users[field].notnull()

    # Drop the original optional fields if not needed
    all_users.drop(columns=optional_fields, inplace=True)

    print(f"{time.time() - start_time:.2f}s: Optional fields flagged.")

    return all_users


def load_activity(super_activity_path: str, non_super_activity_path: str) -> pd.DataFrame:
    """
    Load and preprocess activity data, renaming and concatenating super and non-super user activities.
    """
    start_time = time.time()
    # Columns to load
    activity_cols = ["UserId", "CreationDate", "ActionType"]

    # Load activity data
    super_activity = pd.read_parquet(super_activity_path, columns=activity_cols)
    non_super_activity = pd.read_parquet(non_super_activity_path, columns=activity_cols)
    print(f"{time.time() - start_time:.2f}s: Super and Non-Super Activity loaded.")

    # Rename 'CreationDate' to 'ActivityDate' and convert to datetime
    super_activity.rename(columns={"CreationDate": "ActivityDate"}, inplace=True)
    non_super_activity.rename(columns={"CreationDate": "ActivityDate"}, inplace=True)

    super_activity["ActivityDate"] = pd.to_datetime(super_activity["ActivityDate"], errors="coerce")
    non_super_activity["ActivityDate"] = pd.to_datetime(non_super_activity["ActivityDate"], errors="coerce")

    # Concatenate activities
    activity = pd.concat([super_activity, non_super_activity], ignore_index=True)
    print(f"{time.time() - start_time:.2f}s: Activities concatenated.")

    # Filter out activities with non-positive UserId
    activity = activity[activity["UserId"] > 0]
    print(f"{time.time() - start_time:.2f}s: Activities filtered for positive UserId.")

    return activity


def merge_user_activity(activity: pd.DataFrame, users: pd.DataFrame) -> pd.DataFrame:
    """
    Merge activity data with user data on UserId.
    """
    start_time = time.time()
    user_activity = activity.merge(
        users, left_on="UserId", right_on="Id", how="left"
    ).drop(columns=["Id"])
    print(f"{time.time() - start_time:.2f}s: User and Activity data merged.")
    return user_activity


def process_user_activity(user_activity: pd.DataFrame, days_limit: int) -> pd.DataFrame:
    """
    Calculate DaysSinceRegistration and filter activities within the specified days limit.
    """
    start_time = time.time()
    # Calculate DaysSinceRegistration
    user_activity["DaysSinceRegistration"] = (
        user_activity["ActivityDate"] - user_activity["CreationDate"]
    ).dt.days

    # Filter activities within the limit
    user_activity_limited = user_activity[
        user_activity["DaysSinceRegistration"] <= days_limit
    ].dropna(subset=["UserId", "SuperUser"])
    print(
        f"{time.time() - start_time:.2f}s: User activity processed for days_limit={days_limit}."
    )

    return user_activity_limited


def compute_action_counts(user_activity_limited: pd.DataFrame) -> pd.DataFrame:
    """
    Compute the count of each ActionType for each UserId and SuperUser status.
    """
    start_time = time.time()
    action_counts = (
        user_activity_limited.groupby(["UserId", "SuperUser", "ActionType"])
        .size()
        .reset_index(name="ActionCount")
    )
    print(f"{time.time() - start_time:.2f}s: Action counts computed.")
    return action_counts


def create_full_cross_product(
    action_counts: pd.DataFrame, user_activity_limited: pd.DataFrame, days_limit: int
) -> pd.DataFrame:
    """
    Create a full cross-product of UserId, SuperUser, and ActionType to ensure all combinations exist.
    Merge with action counts and fill missing values with 0.
    Pivot the data so that each ActionType becomes a separate column.
    """
    start_time = time.time()
    # Unique users and actions, including optional field flags
    unique_users = user_activity_limited[
        ["UserId", "SuperUser", "AboutMe_Present", "Location_Present", "WebsiteUrl_Present"]
    ].drop_duplicates()
    unique_actions = user_activity_limited["ActionType"].unique()

    # Create cross product using a key
    unique_users["key"] = 1
    unique_actions_df = pd.DataFrame(unique_actions, columns=["ActionType"])
    unique_actions_df["key"] = 1

    full_index = pd.merge(unique_users, unique_actions_df, on="key").drop("key", axis=1)

    # Merge with action counts
    result = pd.merge(
        full_index, action_counts, on=["UserId", "SuperUser", "ActionType"], how="left"
    )

    # Fill missing ActionCount with 0
    result["ActionCount"] = result["ActionCount"].fillna(0).astype(int)

    # Assign DaysSinceRegistration
    result["DaysSinceRegistration"] = days_limit

    # Pivot the result so that each ActionType becomes a separate column
    pivoted_result = result.pivot_table(
        index=["UserId", "SuperUser", "DaysSinceRegistration",
               "AboutMe_Present", "Location_Present", "WebsiteUrl_Present"],
        columns="ActionType",
        values="ActionCount",
        fill_value=0,
    ).reset_index()

    # Flatten the MultiIndex columns after pivot
    pivoted_result.columns = ["UserId", "SuperUser", "DaysSinceRegistration",
                              "AboutMe_Present", "Location_Present", "WebsiteUrl_Present"] + [
        f"{col}_Count" for col in pivoted_result.columns if col not in ["UserId", "SuperUser", "DaysSinceRegistration",
                                                                          "AboutMe_Present", "Location_Present",
                                                                          "WebsiteUrl_Present"]
    ]

    print(
        f"{time.time() - start_time:.2f}s: Full cross-product and pivot created for days_limit={days_limit}."
    )

    return pivoted_result

# %%
total_start_time = time.time()

# File paths
users_path = "../data/Users.parquet"
super_users_path = "../data/Users_Super.parquet"
super_activity_path = "../data_users/actions_cleaned_SuperUserIds.parquet"
non_super_activity_path = (
    "../data_users/actions_cleaned_NonSuperUserIdsSample_0.1.parquet"
)

# Load and preprocess user data
users_start_time = time.time()
users = load_users(users_path, super_users_path)
print("\nUsers DataFrame:")
print(users.shape)
print(users.head())
print(f"{time.time() - users_start_time:.2f}s: Users loaded and preprocessed.")

# Load and preprocess activity data
activity_start_time = time.time()
activity = load_activity(super_activity_path, non_super_activity_path)
print("\nActivity DataFrame:")
print(activity.shape)
print(activity.head())
print(f"{time.time() - activity_start_time:.2f}s: Activity loaded and preprocessed.")

# Merge user and activity data
merge_start_time = time.time()
user_activity = merge_user_activity(activity, users)
print("\nUser-Activity DataFrame:")
print(user_activity.shape)
print(user_activity.head())
print(f"{time.time() - merge_start_time:.2f}s: User-Activity merged.")

# Initialize a list to collect results for all day limits
all_results = []

# Iterate over each day limit with a progress bar
for days_limit in tqdm(DAY_LIMITS, desc="Processing Day Limits"):
    print(f"\nProcessing for DaysSinceRegistration = {days_limit}")
    step_start_time = time.time()

    # Process user activity within the specified days limit
    user_activity_limited = process_user_activity(user_activity, days_limit)
    print("Limited User-Activity DataFrame:")
    print(user_activity_limited.shape)
    print(user_activity_limited.head())
    print(f"{time.time() - step_start_time:.2f}s: User-Activity limited.")

    # Compute action counts
    action_counts = compute_action_counts(user_activity_limited)
    print("\nAction Counts DataFrame:")
    print(action_counts.shape)
    print(action_counts.head())
    print(f"{time.time() - step_start_time:.2f}s: Action counts computed.")

    # Create full cross-product and pivoted result for current day limit
    result = create_full_cross_product(action_counts, user_activity_limited, days_limit)
    print("\nFinal Pivoted Result DataFrame for current day limit:")
    print(result.shape)
    print(result.head())
    print(
        f"{time.time() - step_start_time:.2f}s: Full cross-product and pivot created for current day limit."
    )

    # Append the pivoted result to the list
    all_results.append(result)
    print(
        f"{time.time() - step_start_time:.2f}s: Processing for days_limit={days_limit} completed."
    )

# Concatenate all results
concatenation_start_time = time.time()
final_result = pd.concat(all_results, ignore_index=True)
print(f"\nAll results concatenated. Final Result DataFrame shape: {final_result.shape}")
print(final_result.head())
print(f"{time.time() - concatenation_start_time:.2f}s: All results concatenated.")

# Save the final result to Parquet
save_start_time = time.time()
output_parquet_path = f"../data_users/results_multiple_days_{MAX_DAYS}.parquet"
final_result.to_parquet(output_parquet_path, index=False)
print(
    f"{time.time() - save_start_time:.2f}s: Final results saved to {output_parquet_path}."
)

print(f"\nTotal processing time: {time.time() - total_start_time:.2f}s.")
# Out:
# 17.70s: Users and Super Users loaded.
# 19.78s: Super Users removed from regular users and concatenated.
# 34.26s: Optional fields flagged.
#
# Users DataFrame:
# (22484218, 6)
#     Id            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present
# 17   2 2008-07-31 14:22:31.287      False             True              True                True
# 18   3 2008-07-31 14:22:31.287      False             True              True                True
# 19   8 2008-07-31 21:33:24.057      False             True             False               False
# 20  10 2008-07-31 21:57:06.240      False             True              True                True
# 21  11 2008-08-01 00:59:11.147      False            False             False               False
# 34.89s: Users loaded and preprocessed.
# 24.01s: Super and Non-Super Activity loaded.
# 56.13s: Activities concatenated.
# 56.59s: Activities filtered for positive UserId.
#
# Activity DataFrame:
# (65242970, 3)
#    UserId        ActivityDate ActionType
# 0     781 2008-09-02 03:41:06   Question
# 1    3434 2008-09-02 03:44:26     Answer
# 2     493 2008-09-02 04:02:40     Answer
# 3     493 2008-09-02 04:06:47     Answer
# 4     658 2008-09-02 04:08:55     Answer
# 57.67s: Activity loaded and preprocessed.
# 9.29s: User and Activity data merged.
#
# User-Activity DataFrame:
# (65242970, 8)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False
# 9.29s: User-Activity merged.
# Processing Day Limits:   0%|          | 0/105 [00:00<?, ?it/s]
# Processing for DaysSinceRegistration = 7
# 1.69s: User activity processed for days_limit=7.
# Limited User-Activity DataFrame:
# (2342338, 9)
#     UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 1     3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 5     2859 2008-09-02 04:12:00     Answer 2008-08-25 15:50:17.907       True             True              True                True                      7
# 8     3742 2008-09-02 04:18:41     Answer 2008-08-30 14:08:11.733       True             True              True                True                      2
# 9     3631 2008-09-02 04:23:34     Answer 2008-08-29 16:06:08.497       True             True              True               False                      3
# 10    3153 2008-09-02 04:36:54   Question 2008-08-27 02:45:05.220       True             True              True                True                      6
# 1.69s: User-Activity limited.
# 0.60s: Action counts computed.
#
# Action Counts DataFrame:
# (1346473, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer            4
# 1       1       True   Question            2
# 2       5       True     Answer            5
# 3       5       True    Comment            2
# 4       5       True   Question            1
# 2.29s: Action counts computed.
# 3.50s: Full cross-product and pivot created for days_limit=7.
#
# Final Pivoted Result DataFrame for current day limit:
# (848667, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                      7             True              True                True           4.0          0.0            0.0             2.0
# 1       5       True                      7             True              True                True           5.0          0.0            2.0             1.0
# 2       9       True                      7             True              True               False           3.0          0.0            0.0             2.0
# 3      13       True                      7             True              True                True          10.0          0.0            1.0             2.0
# 4      17       True                      7             True              True                True          23.0          0.0            1.0             2.0
# 5.81s: Full cross-product and pivot created for current day limit.
# 5.81s: Processing for days_limit=7 completed.
#
# Processing for DaysSinceRegistration = 14
# 1.73s: User activity processed for days_limit=14.
# Limited User-Activity DataFrame:
# (2791871, 9)
#     UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 1     3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 5     2859 2008-09-02 04:12:00     Answer 2008-08-25 15:50:17.907       True             True              True                True                      7
# 8     3742 2008-09-02 04:18:41     Answer 2008-08-30 14:08:11.733       True             True              True                True                      2
# 9     3631 2008-09-02 04:23:34     Answer 2008-08-29 16:06:08.497       True             True              True               False                      3
# 10    3153 2008-09-02 04:36:54   Question 2008-08-27 02:45:05.220       True             True              True                True                      6
# 1.74s: User-Activity limited.
# 0.59s: Action counts computed.
#
# Action Counts DataFrame:
# (1404854, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           16
# 1       1       True    Comment            1
# 2       1       True   Question            4
# 3       5       True     Answer           15
# 4       5       True    Comment            2
# 2.33s: Action counts computed.
# 3.77s: Full cross-product and pivot created for days_limit=14.
#
# Final Pivoted Result DataFrame for current day limit:
# (866333, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     14             True              True                True          16.0          0.0            1.0             4.0
# 1       5       True                     14             True              True                True          15.0          0.0            2.0             1.0
# 2       9       True                     14             True              True               False           4.0          0.0            0.0             2.0
# 3      13       True                     14             True              True                True          22.0          1.0            1.0             2.0
# 4      17       True                     14             True              True                True          40.0          0.0            5.0             3.0
# 6.12s: Full cross-product and pivot created for current day limit.
# 6.12s: Processing for days_limit=14 completed.
#
# Processing for DaysSinceRegistration = 21
# 1.72s: User activity processed for days_limit=21.
# Limited User-Activity DataFrame:
# (3169070, 9)
#     UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 1     3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 5     2859 2008-09-02 04:12:00     Answer 2008-08-25 15:50:17.907       True             True              True                True                      7
# 8     3742 2008-09-02 04:18:41     Answer 2008-08-30 14:08:11.733       True             True              True                True                      2
# 9     3631 2008-09-02 04:23:34     Answer 2008-08-29 16:06:08.497       True             True              True               False                      3
# 10    3153 2008-09-02 04:36:54   Question 2008-08-27 02:45:05.220       True             True              True                True                      6
# 1.73s: User-Activity limited.
# 0.64s: Action counts computed.
#
# Action Counts DataFrame:
# (1443604, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           19
# 1       1       True    Comment            1
# 2       1       True   Question            5
# 3       4       True     Answer            7
# 4       5       True     Answer           52
# 2.37s: Action counts computed.
# 3.75s: Full cross-product and pivot created for days_limit=21.
#
# Final Pivoted Result DataFrame for current day limit:
# (877776, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     21             True              True                True          19.0          0.0            1.0             5.0
# 1       4       True                     21             True              True                True           7.0          0.0            0.0             0.0
# 2       5       True                     21             True              True                True          52.0          0.0            2.0             5.0
# 3       9       True                     21             True              True               False           6.0          0.0            0.0             3.0
# 4      13       True                     21             True              True                True          23.0          1.0            1.0             2.0
# 6.13s: Full cross-product and pivot created for current day limit.
# 6.13s: Processing for days_limit=21 completed.
#
# Processing for DaysSinceRegistration = 28
# 1.85s: User activity processed for days_limit=28.
# Limited User-Activity DataFrame:
# (3513276, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.86s: User-Activity limited.
# 0.79s: Action counts computed.
#
# Action Counts DataFrame:
# (1473912, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           25
# 1       1       True    Comment            2
# 2       1       True   Question            5
# 3       4       True     Answer            9
# 4       5       True     Answer           60
# 2.65s: Action counts computed.
# 3.84s: Full cross-product and pivot created for days_limit=28.
#
# Final Pivoted Result DataFrame for current day limit:
# (886823, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     28             True              True                True          25.0          0.0            2.0             5.0
# 1       4       True                     28             True              True                True           9.0          0.0            0.0             0.0
# 2       5       True                     28             True              True                True          60.0          0.0            2.0             8.0
# 3       9       True                     28             True              True               False          13.0          0.0            0.0             3.0
# 4      13       True                     28             True              True                True          28.0          1.0            3.0             2.0
# 6.52s: Full cross-product and pivot created for current day limit.
# 6.52s: Processing for days_limit=28 completed.
#
# Processing for DaysSinceRegistration = 35
# 1.84s: User activity processed for days_limit=35.
# Limited User-Activity DataFrame:
# (3831296, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.85s: User-Activity limited.
# 0.72s: Action counts computed.
#
# Action Counts DataFrame:
# (1498020, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           26
# 1       1       True    Comment            2
# 2       1       True   Question            5
# 3       4       True     Answer            9
# 4       5       True     Answer           64
# 2.58s: Action counts computed.
# 3.95s: Full cross-product and pivot created for days_limit=35.
#
# Final Pivoted Result DataFrame for current day limit:
# (893837, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     35             True              True                True          26.0          0.0            2.0             5.0
# 1       4       True                     35             True              True                True           9.0          0.0            0.0             0.0
# 2       5       True                     35             True              True                True          64.0          0.0            2.0             9.0
# 3       9       True                     35             True              True               False          13.0          0.0            1.0             3.0
# 4      13       True                     35             True              True                True          28.0          1.0            3.0             2.0
# 6.56s: Full cross-product and pivot created for current day limit.
# 6.56s: Processing for days_limit=35 completed.
#
# Processing for DaysSinceRegistration = 42
# 2.02s: User activity processed for days_limit=42.
# Limited User-Activity DataFrame:
# (4132698, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.03s: User-Activity limited.
# 0.86s: Action counts computed.
#
# Action Counts DataFrame:
# (1518765, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           29
# 1       1       True    Comment            7
# 2       1       True   Question            5
# 3       4       True     Answer            9
# 4       5       True     Answer           72
# 2.90s: Action counts computed.
# 4.04s: Full cross-product and pivot created for days_limit=42.
#
# Final Pivoted Result DataFrame for current day limit:
# (899843, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     42             True              True                True          29.0          0.0            7.0             5.0
# 1       4       True                     42             True              True                True           9.0          0.0            0.0             0.0
# 2       5       True                     42             True              True                True          72.0          0.0            3.0            10.0
# 3       9       True                     42             True              True               False          13.0          0.0            1.0             3.0
# 4      13       True                     42             True              True                True          29.0          1.0            3.0             2.0
# 6.96s: Full cross-product and pivot created for current day limit.
# 6.96s: Processing for days_limit=42 completed.
#
# Processing for DaysSinceRegistration = 49
# 1.89s: User activity processed for days_limit=49.
# Limited User-Activity DataFrame:
# (4416382, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.91s: User-Activity limited.
# 0.79s: Action counts computed.
#
# Action Counts DataFrame:
# (1536980, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           31
# 1       1       True      Badge           39
# 2       1       True    Comment           18
# 3       1       True   Question            5
# 4       4       True     Answer           12
# 2.70s: Action counts computed.
# 3.90s: Full cross-product and pivot created for days_limit=49.
#
# Final Pivoted Result DataFrame for current day limit:
# (905083, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     49             True              True                True          31.0         39.0           18.0             5.0
# 1       4       True                     49             True              True                True          12.0         18.0            3.0             1.0
# 2       5       True                     49             True              True                True          81.0         21.0            6.0            11.0
# 3       9       True                     49             True              True               False          13.0         10.0            1.0             3.0
# 4      13       True                     49             True              True                True          56.0         26.0           59.0             3.0
# 6.62s: Full cross-product and pivot created for current day limit.
# 6.62s: Processing for days_limit=49 completed.
#
# Processing for DaysSinceRegistration = 56
# 1.86s: User activity processed for days_limit=56.
# Limited User-Activity DataFrame:
# (4685503, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.88s: User-Activity limited.
# 0.82s: Action counts computed.
#
# Action Counts DataFrame:
# (1553295, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           33
# 1       1       True      Badge           43
# 2       1       True    Comment           19
# 3       1       True   Question            6
# 4       4       True     Answer           13
# 2.71s: Action counts computed.
# 3.99s: Full cross-product and pivot created for days_limit=56.
#
# Final Pivoted Result DataFrame for current day limit:
# (909782, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     56             True              True                True          33.0         43.0           19.0             6.0
# 1       4       True                     56             True              True                True          13.0         22.0            5.0             2.0
# 2       5       True                     56             True              True                True          86.0         24.0            6.0            11.0
# 3       9       True                     56             True              True               False          13.0         10.0            1.0             3.0
# 4      13       True                     56             True              True                True          87.0         34.0          104.0             3.0
# 6.72s: Full cross-product and pivot created for current day limit.
# 6.72s: Processing for days_limit=56 completed.
#
# Processing for DaysSinceRegistration = 63
# 1.83s: User activity processed for days_limit=63.
# Limited User-Activity DataFrame:
# (4944411, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.85s: User-Activity limited.
# 0.81s: Action counts computed.
#
# Action Counts DataFrame:
# (1567934, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           35
# 1       1       True      Badge           44
# 2       1       True    Comment           19
# 3       1       True   Question            6
# 4       4       True     Answer           14
# 2.66s: Action counts computed.
# 3.84s: Full cross-product and pivot created for days_limit=63.
#
# Final Pivoted Result DataFrame for current day limit:
# (914112, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     63             True              True                True          35.0         44.0           19.0             6.0
# 1       4       True                     63             True              True                True          14.0         24.0            5.0             2.0
# 2       5       True                     63             True              True                True          86.0         27.0            6.0            13.0
# 3       9       True                     63             True              True               False          13.0         10.0            1.0             3.0
# 4      13       True                     63             True              True                True         132.0         42.0          172.0             3.0
# 6.52s: Full cross-product and pivot created for current day limit.
# 6.52s: Processing for days_limit=63 completed.
#
# Processing for DaysSinceRegistration = 70
# 1.89s: User activity processed for days_limit=70.
# Limited User-Activity DataFrame:
# (5193475, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.92s: User-Activity limited.
# 0.82s: Action counts computed.
#
# Action Counts DataFrame:
# (1581425, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           40
# 1       1       True      Badge           46
# 2       1       True    Comment           25
# 3       1       True   Question            6
# 4       4       True     Answer           14
# 2.74s: Action counts computed.
# 3.88s: Full cross-product and pivot created for days_limit=70.
#
# Final Pivoted Result DataFrame for current day limit:
# (918059, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     70             True              True                True          40.0         46.0           25.0             6.0
# 1       4       True                     70             True              True                True          14.0         24.0            5.0             2.0
# 2       5       True                     70             True              True                True          86.0         29.0            8.0            16.0
# 3       9       True                     70             True              True               False          15.0         10.0            1.0             3.0
# 4      13       True                     70             True              True                True         149.0         47.0          193.0             3.0
# 6.64s: Full cross-product and pivot created for current day limit.
# 6.64s: Processing for days_limit=70 completed.
#
# Processing for DaysSinceRegistration = 77
# 1.89s: User activity processed for days_limit=77.
# Limited User-Activity DataFrame:
# (5434828, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.91s: User-Activity limited.
# 0.87s: Action counts computed.
#
# Action Counts DataFrame:
# (1594051, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           44
# 1       1       True      Badge           49
# 2       1       True    Comment           29
# 3       1       True   Question            6
# 4       4       True     Answer           14
# 2.79s: Action counts computed.
# 4.01s: Full cross-product and pivot created for days_limit=77.
#
# Final Pivoted Result DataFrame for current day limit:
# (921686, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     77             True              True                True          44.0         49.0           29.0             6.0
# 1       4       True                     77             True              True                True          14.0         25.0            5.0             2.0
# 2       5       True                     77             True              True                True          87.0         30.0            8.0            16.0
# 3       9       True                     77             True              True               False          16.0         10.0            1.0             3.0
# 4      13       True                     77             True              True                True         188.0         59.0          244.0             3.0
# 6.82s: Full cross-product and pivot created for current day limit.
# 6.82s: Processing for days_limit=77 completed.
#
# Processing for DaysSinceRegistration = 84
# 1.88s: User activity processed for days_limit=84.
# Limited User-Activity DataFrame:
# (5669504, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.91s: User-Activity limited.
# 0.89s: Action counts computed.
#
# Action Counts DataFrame:
# (1606094, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           46
# 1       1       True      Badge           55
# 2       1       True    Comment           35
# 3       1       True   Question            7
# 4       4       True     Answer           14
# 2.80s: Action counts computed.
# 4.25s: Full cross-product and pivot created for days_limit=84.
#
# Final Pivoted Result DataFrame for current day limit:
# (925167, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     84             True              True                True          46.0         55.0           35.0             7.0
# 1       4       True                     84             True              True                True          14.0         25.0            5.0             2.0
# 2       5       True                     84             True              True                True          88.0         32.0            8.0            16.0
# 3       9       True                     84             True              True               False          16.0         10.0            1.0             3.0
# 4      13       True                     84             True              True                True         207.0         65.0          270.0             3.0
# 7.07s: Full cross-product and pivot created for current day limit.
# 7.07s: Processing for days_limit=84 completed.
#
# Processing for DaysSinceRegistration = 91
# 1.97s: User activity processed for days_limit=91.
# Limited User-Activity DataFrame:
# (5894946, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 1.99s: User-Activity limited.
# 1.08s: Action counts computed.
#
# Action Counts DataFrame:
# (1617145, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           48
# 1       1       True      Badge           60
# 2       1       True    Comment           35
# 3       1       True   Question            7
# 4       4       True     Answer           14
# 3.08s: Action counts computed.
# 4.11s: Full cross-product and pivot created for days_limit=91.
#
# Final Pivoted Result DataFrame for current day limit:
# (928399, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     91             True              True                True          48.0         60.0           35.0             7.0
# 1       4       True                     91             True              True                True          14.0         25.0            5.0             2.0
# 2       5       True                     91             True              True                True          88.0         32.0            8.0            16.0
# 3       9       True                     91             True              True               False          16.0         10.0            1.0             3.0
# 4      13       True                     91             True              True                True         218.0         70.0          279.0             3.0
# 7.21s: Full cross-product and pivot created for current day limit.
# 7.21s: Processing for days_limit=91 completed.
#
# Processing for DaysSinceRegistration = 98
# 2.18s: User activity processed for days_limit=98.
# Limited User-Activity DataFrame:
# (6116484, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.21s: User-Activity limited.
# 1.34s: Action counts computed.
#
# Action Counts DataFrame:
# (1627866, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           50
# 1       1       True      Badge           61
# 2       1       True    Comment           35
# 3       1       True   Question            7
# 4       4       True     Answer           15
# 3.56s: Action counts computed.
# 4.10s: Full cross-product and pivot created for days_limit=98.
#
# Final Pivoted Result DataFrame for current day limit:
# (931424, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                     98             True              True                True          50.0         61.0           35.0             7.0
# 1       4       True                     98             True              True                True          15.0         25.0            5.0             2.0
# 2       5       True                     98             True              True                True          88.0         33.0            8.0            16.0
# 3       9       True                     98             True              True               False          16.0         10.0            1.0             3.0
# 4      13       True                     98             True              True                True         229.0         72.0          284.0             3.0
# 7.68s: Full cross-product and pivot created for current day limit.
# 7.68s: Processing for days_limit=98 completed.
#
# Processing for DaysSinceRegistration = 105
# 1.98s: User activity processed for days_limit=105.
# Limited User-Activity DataFrame:
# (6334424, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.00s: User-Activity limited.
# 1.03s: Action counts computed.
#
# Action Counts DataFrame:
# (1638112, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           52
# 1       1       True      Badge           61
# 2       1       True    Comment           37
# 3       1       True   Question            7
# 4       4       True     Answer           15
# 3.03s: Action counts computed.
# 4.14s: Full cross-product and pivot created for days_limit=105.
#
# Final Pivoted Result DataFrame for current day limit:
# (934362, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    105             True              True                True          52.0         61.0           37.0             7.0
# 1       4       True                    105             True              True                True          15.0         25.0            5.0             2.0
# 2       5       True                    105             True              True                True          88.0         34.0            8.0            16.0
# 3       9       True                    105             True              True               False          16.0         10.0            1.0             3.0
# 4      13       True                    105             True              True                True         239.0         74.0          305.0             3.0
# 7.19s: Full cross-product and pivot created for current day limit.
# 7.19s: Processing for days_limit=105 completed.
#
# Processing for DaysSinceRegistration = 112
# 1.98s: User activity processed for days_limit=112.
# Limited User-Activity DataFrame:
# (6550699, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.00s: User-Activity limited.
# 1.05s: Action counts computed.
#
# Action Counts DataFrame:
# (1648003, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           53
# 1       1       True      Badge           61
# 2       1       True    Comment           38
# 3       1       True   Question            7
# 4       4       True     Answer           16
# 3.06s: Action counts computed.
# 4.21s: Full cross-product and pivot created for days_limit=112.
#
# Final Pivoted Result DataFrame for current day limit:
# (937166, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    112             True              True                True          53.0         61.0           38.0             7.0
# 1       4       True                    112             True              True                True          16.0         25.0            5.0             2.0
# 2       5       True                    112             True              True                True          89.0         34.0            8.0            16.0
# 3       9       True                    112             True              True               False          16.0         10.0            1.0             3.0
# 4      13       True                    112             True              True                True         248.0         77.0          314.0             3.0
# 7.29s: Full cross-product and pivot created for current day limit.
# 7.29s: Processing for days_limit=112 completed.
#
# Processing for DaysSinceRegistration = 119
# 1.98s: User activity processed for days_limit=119.
# Limited User-Activity DataFrame:
# (6766790, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.00s: User-Activity limited.
# 1.04s: Action counts computed.
#
# Action Counts DataFrame:
# (1657469, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer           53
# 1       1       True      Badge           61
# 2       1       True    Comment           43
# 3       1       True   Question            8
# 4       4       True     Answer           16
# 3.05s: Action counts computed.
# 4.23s: Full cross-product and pivot created for days_limit=119.
#
# Final Pivoted Result DataFrame for current day limit:
# (939867, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    119             True              True                True          53.0         61.0           43.0             8.0
# 1       4       True                    119             True              True                True          16.0         25.0            5.0             2.0
# 2       5       True                    119             True              True                True          89.0         34.0            8.0            16.0
# 3       9       True                    119             True              True               False          16.0         12.0            1.0             3.0
# 4      13       True                    119             True              True                True         252.0         77.0          328.0             3.0
# 7.30s: Full cross-product and pivot created for current day limit.
# 7.30s: Processing for days_limit=119 completed.
#
# Processing for DaysSinceRegistration = 126
# 1.97s: User activity processed for days_limit=126.
# Limited User-Activity DataFrame:
# (6979229, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# ...
# 4.84s: Action counts computed.
# 5.73s: Full cross-product and pivot created for days_limit=497.
#
# Final Pivoted Result DataFrame for current day limit:
# (1020204, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    497             True              True                True         103.0        129.0          183.0            16.0
# 1       4       True                    497             True              True                True          51.0         66.0           24.0             8.0
# 2       5       True                    497             True              True                True         244.0         96.0           83.0            32.0
# 3       9       True                    497             True              True               False          24.0         20.0            3.0             7.0
# 4      13       True                    497             True              True                True         442.0        127.0          706.0             4.0
# 10.59s: Full cross-product and pivot created for current day limit.
# 10.59s: Processing for days_limit=497 completed.
#
# Processing for DaysSinceRegistration = 504
# 6.38s: User activity processed for days_limit=504.
# Limited User-Activity DataFrame:
# (17788102, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 6.53s: User-Activity limited.
# 2.42s: Action counts computed.
#
# Action Counts DataFrame:
# (1952750, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer          103
# 1       1       True      Badge          129
# 2       1       True    Comment          185
# 3       1       True   Question           16
# 4       4       True     Answer           52
# 8.96s: Action counts computed.
# 5.69s: Full cross-product and pivot created for days_limit=504.
#
# Final Pivoted Result DataFrame for current day limit:
# (1021067, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    504             True              True                True         103.0        129.0          185.0            16.0
# 1       4       True                    504             True              True                True          52.0         66.0           25.0            10.0
# 2       5       True                    504             True              True                True         244.0         97.0           83.0            32.0
# 3       9       True                    504             True              True               False          24.0         20.0            3.0             7.0
# 4      13       True                    504             True              True                True         443.0        127.0          708.0             4.0
# 14.68s: Full cross-product and pivot created for current day limit.
# 14.68s: Processing for days_limit=504 completed.
#
# Processing for DaysSinceRegistration = 511
# 3.08s: User activity processed for days_limit=511.
# Limited User-Activity DataFrame:
# (17977144, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 3.15s: User-Activity limited.
# 2.09s: Action counts computed.
#
# Action Counts DataFrame:
# (1956113, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer          103
# 1       1       True      Badge          129
# 2       1       True    Comment          189
# 3       1       True   Question           16
# 4       4       True     Answer           52
# 5.25s: Action counts computed.
# 5.53s: Full cross-product and pivot created for days_limit=511.
#
# Final Pivoted Result DataFrame for current day limit:
# (1021937, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    511             True              True                True         103.0        129.0          189.0            16.0
# 1       4       True                    511             True              True                True          52.0         66.0           25.0            10.0
# 2       5       True                    511             True              True                True         244.0         97.0           83.0            32.0
# 3       9       True                    511             True              True               False          24.0         20.0            3.0             7.0
# 4      13       True                    511             True              True                True         443.0        127.0          710.0             4.0
# 10.80s: Full cross-product and pivot created for current day limit.
# 10.80s: Processing for days_limit=511 completed.
#
# Processing for DaysSinceRegistration = 518
# 2.46s: User activity processed for days_limit=518.
# Limited User-Activity DataFrame:
# (18167906, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.52s: User-Activity limited.
# 1.98s: Action counts computed.
#
# Action Counts DataFrame:
# (1959332, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer          103
# 1       1       True      Badge          129
# 2       1       True    Comment          192
# 3       1       True   Question           16
# 4       4       True     Answer           52
# 4.51s: Action counts computed.
# 5.66s: Full cross-product and pivot created for days_limit=518.
#
# Final Pivoted Result DataFrame for current day limit:
# (1022766, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    518             True              True                True         103.0        129.0          192.0            16.0
# 1       4       True                    518             True              True                True          52.0         66.0           25.0            10.0
# 2       5       True                    518             True              True                True         244.0         97.0           84.0            32.0
# 3       9       True                    518             True              True               False          24.0         20.0            3.0             7.0
# 4      13       True                    518             True              True                True         446.0        128.0          711.0             4.0
# 10.20s: Full cross-product and pivot created for current day limit.
# 10.20s: Processing for days_limit=518 completed.
#
# Processing for DaysSinceRegistration = 525
# 2.53s: User activity processed for days_limit=525.
# Limited User-Activity DataFrame:
# (18359675, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.59s: User-Activity limited.
# 2.12s: Action counts computed.
#
# Action Counts DataFrame:
# (1962568, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer          104
# 1       1       True      Badge          131
# 2       1       True    Comment          196
# 3       1       True   Question           16
# 4       4       True     Answer           52
# 4.72s: Action counts computed.
# 6.57s: Full cross-product and pivot created for days_limit=525.
#
# Final Pivoted Result DataFrame for current day limit:
# (1023609, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    525             True              True                True         104.0        131.0          196.0            16.0
# 1       4       True                    525             True              True                True          52.0         67.0           25.0            10.0
# 2       5       True                    525             True              True                True         244.0         97.0           84.0            32.0
# 3       9       True                    525             True              True               False          25.0         20.0            3.0             7.0
# 4      13       True                    525             True              True                True         458.0        128.0          753.0             4.0
# 11.31s: Full cross-product and pivot created for current day limit.
# 11.31s: Processing for days_limit=525 completed.
#
# Processing for DaysSinceRegistration = 532
# 2.92s: User activity processed for days_limit=532.
# Limited User-Activity DataFrame:
# (18548316, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 3.00s: User-Activity limited.
# 2.05s: Action counts computed.
#
# Action Counts DataFrame:
# (1965771, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer          108
# 1       1       True      Badge          131
# 2       1       True    Comment          199
# 3       1       True   Question           16
# 4       4       True     Answer           52
# 5.06s: Action counts computed.
# 5.41s: Full cross-product and pivot created for days_limit=532.
#
# Final Pivoted Result DataFrame for current day limit:
# (1024486, 10)
#    UserId  SuperUser  DaysSinceRegistration  AboutMe_Present  Location_Present  WebsiteUrl_Present  Answer_Count  Badge_Count  Comment_Count  Question_Count
# 0       1       True                    532             True              True                True         108.0        131.0          199.0            16.0
# 1       4       True                    532             True              True                True          52.0         67.0           25.0            10.0
# 2       5       True                    532             True              True                True         245.0         98.0           84.0            32.0
# 3       9       True                    532             True              True               False          27.0         20.0            3.0             7.0
# 4      13       True                    532             True              True                True         472.0        129.0          781.0             4.0
# 10.49s: Full cross-product and pivot created for current day limit.
# 10.49s: Processing for days_limit=532 completed.
#
# Processing for DaysSinceRegistration = 539
# 2.55s: User activity processed for days_limit=539.
# Limited User-Activity DataFrame:
# (18733980, 9)
#    UserId        ActivityDate ActionType            CreationDate  SuperUser  AboutMe_Present  Location_Present  WebsiteUrl_Present  DaysSinceRegistration
# 0     781 2008-09-02 03:41:06   Question 2008-08-08 21:28:19.890       True             True              True                True                     24
# 1    3434 2008-09-02 03:44:26     Answer 2008-08-28 15:06:22.043       True             True              True                True                      4
# 2     493 2008-09-02 04:02:40     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 3     493 2008-09-02 04:06:47     Answer 2008-08-06 10:25:05.493       True             True              True                True                     26
# 4     658 2008-09-02 04:08:55     Answer 2008-08-07 15:07:47.713       True             True             False               False                     25
# 2.62s: User-Activity limited.
# 2.22s: Action counts computed.
#
# Action Counts DataFrame:
# (1968883, 4)
#    UserId  SuperUser ActionType  ActionCount
# 0       1       True     Answer          108
# 1       1       True      Badge          132
# 2       1       True    Comment          202
# 3       1       True   Question           16
# 4       4       True     Answer           52
# 4.84s: Action counts computed.
